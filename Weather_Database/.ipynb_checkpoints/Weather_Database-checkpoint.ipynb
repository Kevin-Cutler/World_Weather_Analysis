# %%
# %matplotlib inline

# %%
#add Dependencies
import pandas as pd
import matplotlib.pyplot as plt
import random
import numpy as np
import timeit
import requests
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy
# Import the API key.
from config import weather_api_key
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(-90.000, 90.000, size=2000)
lngs = np.random.uniform(-180.000, 180.000, size=2000)
lats_lngs = zip(lats, lngs)
lats_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lats_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 751

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=473cca902aff3a88f36cec7c4672a616

# %%
#Empty city_data list
city_data = []
print("Beginning Data Retrieval")
print("-----------------------------")

#create counters
record_count = 1
set_count = 1


# Loop through all the cities in our list.
for i, city in enumerate(cities):
    
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    
     # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
     # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        weather_desc = city_weather['weather'][0]['description']
        
         # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current Description": weather_desc})
        
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | zaranj
# Processing Record 2 of Set 1 | butaritari
# Processing Record 3 of Set 1 | punta arenas
# Processing Record 4 of Set 1 | hobart
# Processing Record 5 of Set 1 | rikitea
# Processing Record 6 of Set 1 | hofn
# Processing Record 7 of Set 1 | puerto ayora
# Processing Record 8 of Set 1 | kidal
# Processing Record 9 of Set 1 | isabela
# Processing Record 10 of Set 1 | big spring
# Processing Record 11 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 12 of Set 1 | kapaa
# Processing Record 13 of Set 1 | kahului
# Processing Record 14 of Set 1 | vaini
# Processing Record 15 of Set 1 | sambava
# Processing Record 16 of Set 1 | chumikan
# Processing Record 17 of Set 1 | busselton
# Processing Record 18 of Set 1 | pevek
# Processing Record 19 of Set 1 | yeppoon
# Processing Record 20 of Set 1 | bethel
# Processing Record 21 of Set 1 | kloulklubed
# Processing Record 22 of Set 1 | saint-joseph
# Processing Record 23 of Set 1 | kodiak
# Processing Record 24 of Set 1 | mataura
# Processing Record 25 of Set 1 | albany
# Processing Record 26 of Set 1 | porto novo
# Processing Record 27 of Set 1 | meulaboh
# Processing Record 28 of Set 1 | tuktoyaktuk
# Processing Record 29 of Set 1 | kavieng
# Processing Record 30 of Set 1 | carnarvon
# Processing Record 31 of Set 1 | mlonggo
# Processing Record 32 of Set 1 | grindavik
# Processing Record 33 of Set 1 | monte carmelo
# Processing Record 34 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 35 of Set 1 | mehamn
# Processing Record 36 of Set 1 | berdigestyakh
# Processing Record 37 of Set 1 | hermanus
# Processing Record 38 of Set 1 | iralaya
# Processing Record 39 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 40 of Set 1 | khatanga
# Processing Record 41 of Set 1 | vila velha
# Processing Record 42 of Set 1 | ushuaia
# Processing Record 43 of Set 1 | klaksvik
# Processing Record 44 of Set 1 | qaanaaq
# Processing Record 45 of Set 1 | sorland
# Processing Record 46 of Set 1 | esperance
# Processing Record 47 of Set 1 | kruisfontein
# Processing Record 48 of Set 1 | rusape
# Processing Record 49 of Set 1 | cape town
# Processing Record 50 of Set 1 | coahuayana
# Processing Record 1 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 2 of Set 2 | ponta do sol
# Processing Record 3 of Set 2 | jamestown
# Processing Record 4 of Set 2 | nabire
# Processing Record 5 of Set 2 | tsagan aman
# Processing Record 6 of Set 2 | nhamunda
# Processing Record 7 of Set 2 | bredasdorp
# Processing Record 8 of Set 2 | sabang
# Processing Record 9 of Set 2 | arraial do cabo
# Processing Record 10 of Set 2 | provideniya
# Processing Record 11 of Set 2 | abbeville
# Processing Record 12 of Set 2 | new norfolk
# Processing Record 13 of Set 2 | boa vista
# Processing Record 14 of Set 2 | port keats
# Processing Record 15 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 16 of Set 2 | leku
# Processing Record 17 of Set 2 | ribeira grande
# Processing Record 18 of Set 2 | saint-philippe
# Processing Record 19 of Set 2 | lagoa
# Processing Record 20 of Set 2 | moron
# Processing Record 21 of Set 2 | mayor pablo lagerenza
# Processing Record 22 of Set 2 | hasaki
# Processing Record 23 of Set 2 | caravelas
# Processing Record 24 of Set 2 | ust-omchug
# Processing Record 25 of Set 2 | ariquemes
# Processing Record 26 of Set 2 | bengkulu
# Processing Record 27 of Set 2 | atuona
# Processing Record 28 of Set 2 | puerto ayacucho
# Processing Record 29 of Set 2 | kajaani
# Processing Record 30 of Set 2 | codrington
# Processing Record 31 of Set 2 | mount isa
# Processing Record 32 of Set 2 | east london
# Processing Record 33 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 34 of Set 2 | aklavik
# Processing Record 35 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 36 of Set 2 | mogadouro
# Processing Record 37 of Set 2 | poum
# Processing Record 38 of Set 2 | saint anthony
# Processing Record 39 of Set 2 | nikolskoye
# Processing Record 40 of Set 2 | flin flon
# Processing Record 41 of Set 2 | manaure
# Processing Record 42 of Set 2 | terme
# Processing Record 43 of Set 2 | barrow
# Processing Record 44 of Set 2 | tripoli
# Processing Record 45 of Set 2 | lebu
# Processing Record 46 of Set 2 | isangel
# Processing Record 47 of Set 2 | laguna
# Processing Record 48 of Set 2 | zhigansk
# Processing Record 49 of Set 2 | agua dulce
# Processing Record 50 of Set 2 | bluff
# Processing Record 1 of Set 3 | arona
# Processing Record 2 of Set 3 | tongzi
# Processing Record 3 of Set 3 | port alfred
# Processing Record 4 of Set 3 | hilo
# Processing Record 5 of Set 3 | davila
# Processing Record 6 of Set 3 | chuy
# Processing Record 7 of Set 3 | bacuit
# City not found. Skipping...
# Processing Record 8 of Set 3 | pine hill
# Processing Record 9 of Set 3 | awjilah
# Processing Record 10 of Set 3 | bogalusa
# Processing Record 11 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 12 of Set 3 | ilula
# Processing Record 13 of Set 3 | bukama
# Processing Record 14 of Set 3 | port lincoln
# Processing Record 15 of Set 3 | stettler
# Processing Record 16 of Set 3 | snasa
# Processing Record 17 of Set 3 | asau
# Processing Record 18 of Set 3 | ashqelon
# Processing Record 19 of Set 3 | tilichiki
# Processing Record 20 of Set 3 | castro
# Processing Record 21 of Set 3 | portland
# Processing Record 22 of Set 3 | magistralnyy
# Processing Record 23 of Set 3 | labutta
# City not found. Skipping...
# Processing Record 24 of Set 3 | clyde river
# Processing Record 25 of Set 3 | avarua
# Processing Record 26 of Set 3 | avera
# Processing Record 27 of Set 3 | nicoya
# Processing Record 28 of Set 3 | atchison
# Processing Record 29 of Set 3 | lata
# Processing Record 30 of Set 3 | nome
# Processing Record 31 of Set 3 | santa rosa
# Processing Record 32 of Set 3 | norman wells
# Processing Record 33 of Set 3 | cidreira
# Processing Record 34 of Set 3 | tarata
# Processing Record 35 of Set 3 | nyurba
# Processing Record 36 of Set 3 | mogzon
# Processing Record 37 of Set 3 | burnie
# Processing Record 38 of Set 3 | urmary
# Processing Record 39 of Set 3 | owando
# Processing Record 40 of Set 3 | georgetown
# Processing Record 41 of Set 3 | campanha
# Processing Record 42 of Set 3 | hualmay
# Processing Record 43 of Set 3 | omboue
# Processing Record 44 of Set 3 | longyearbyen
# Processing Record 45 of Set 3 | sola
# Processing Record 46 of Set 3 | loding
# Processing Record 47 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 48 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 49 of Set 3 | kita
# Processing Record 50 of Set 3 | upernavik
# Processing Record 1 of Set 4 | vanavara
# Processing Record 2 of Set 4 | gushikawa
# Processing Record 3 of Set 4 | nanortalik
# Processing Record 4 of Set 4 | tautira
# Processing Record 5 of Set 4 | kaitangata
# Processing Record 6 of Set 4 | karratha
# Processing Record 7 of Set 4 | marsa matruh
# Processing Record 8 of Set 4 | yellowknife
# Processing Record 9 of Set 4 | saint george
# Processing Record 10 of Set 4 | camacha
# Processing Record 11 of Set 4 | ostersund
# Processing Record 12 of Set 4 | odesskoye
# Processing Record 13 of Set 4 | tuatapere
# Processing Record 14 of Set 4 | vanimo
# Processing Record 15 of Set 4 | port elizabeth
# Processing Record 16 of Set 4 | sakakah
# Processing Record 17 of Set 4 | sawakin
# Processing Record 18 of Set 4 | raudeberg
# Processing Record 19 of Set 4 | karakendzha
# City not found. Skipping...
# Processing Record 20 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 21 of Set 4 | lavrentiya
# Processing Record 22 of Set 4 | padang
# Processing Record 23 of Set 4 | conde
# Processing Record 24 of Set 4 | aguas vermelhas
# Processing Record 25 of Set 4 | katsuura
# Processing Record 26 of Set 4 | beeville
# Processing Record 27 of Set 4 | haysville
# Processing Record 28 of Set 4 | san cristobal
# Processing Record 29 of Set 4 | tabuny
# Processing Record 30 of Set 4 | camacupa
# Processing Record 31 of Set 4 | pimenta bueno
# Processing Record 32 of Set 4 | churapcha
# Processing Record 33 of Set 4 | zhanatas
# City not found. Skipping...
# Processing Record 34 of Set 4 | narsaq
# Processing Record 35 of Set 4 | barawe
# City not found. Skipping...
# Processing Record 36 of Set 4 | bongandanga
# Processing Record 37 of Set 4 | bumba
# Processing Record 38 of Set 4 | itarema
# Processing Record 39 of Set 4 | san patricio
# Processing Record 40 of Set 4 | kimbe
# Processing Record 41 of Set 4 | thompson
# Processing Record 42 of Set 4 | concepcion del oro
# Processing Record 43 of Set 4 | codroipo
# Processing Record 44 of Set 4 | coihaique
# Processing Record 45 of Set 4 | kysyl-syr
# Processing Record 46 of Set 4 | burica
# City not found. Skipping...
# Processing Record 47 of Set 4 | chak jhumra
# Processing Record 48 of Set 4 | vangaindrano
# Processing Record 49 of Set 4 | victoria point
# Processing Record 50 of Set 4 | huaihua
# Processing Record 1 of Set 5 | kiama
# Processing Record 2 of Set 5 | beringovskiy
# Processing Record 3 of Set 5 | asosa
# Processing Record 4 of Set 5 | mumbwa
# Processing Record 5 of Set 5 | faya
# Processing Record 6 of Set 5 | ancud
# Processing Record 7 of Set 5 | kungurtug
# Processing Record 8 of Set 5 | fort nelson
# Processing Record 9 of Set 5 | mar del plata
# Processing Record 10 of Set 5 | saskylakh
# Processing Record 11 of Set 5 | souillac
# Processing Record 12 of Set 5 | jieshi
# Processing Record 13 of Set 5 | sioux lookout
# Processing Record 14 of Set 5 | riyadh
# Processing Record 15 of Set 5 | vidim
# Processing Record 16 of Set 5 | coolum beach
# Processing Record 17 of Set 5 | tasiilaq
# Processing Record 18 of Set 5 | herat
# Processing Record 19 of Set 5 | mahebourg
# Processing Record 20 of Set 5 | quatre cocos
# Processing Record 21 of Set 5 | skelleftea
# Processing Record 22 of Set 5 | novaya zaimka
# Processing Record 23 of Set 5 | san quintin
# Processing Record 24 of Set 5 | pakwach
# City not found. Skipping...
# Processing Record 25 of Set 5 | bokhan
# Processing Record 26 of Set 5 | mandalgovi
# Processing Record 27 of Set 5 | college
# Processing Record 28 of Set 5 | torbay
# Processing Record 29 of Set 5 | moose factory
# Processing Record 30 of Set 5 | gimli
# Processing Record 31 of Set 5 | dikson
# Processing Record 32 of Set 5 | trelew
# Processing Record 33 of Set 5 | kaniama
# Processing Record 34 of Set 5 | aden
# Processing Record 35 of Set 5 | chalinze
# Processing Record 36 of Set 5 | carahue
# Processing Record 37 of Set 5 | bambous virieux
# Processing Record 38 of Set 5 | faanui
# Processing Record 39 of Set 5 | tandil
# Processing Record 40 of Set 5 | kudahuvadhoo
# Processing Record 41 of Set 5 | aransas pass
# Processing Record 42 of Set 5 | fare
# Processing Record 43 of Set 5 | geraldton
# Processing Record 44 of Set 5 | clarence town
# Processing Record 45 of Set 5 | chernyshevskiy
# Processing Record 46 of Set 5 | lorengau
# Processing Record 47 of Set 5 | udachnyy
# Processing Record 48 of Set 5 | deputatskiy
# Processing Record 49 of Set 5 | zhumadian
# Processing Record 50 of Set 5 | varzelandia
# Processing Record 1 of Set 6 | atlantic city
# Processing Record 2 of Set 6 | toktogul
# Processing Record 3 of Set 6 | chapar
# Processing Record 4 of Set 6 | voyvozh
# Processing Record 5 of Set 6 | coquimbo
# Processing Record 6 of Set 6 | shingu
# Processing Record 7 of Set 6 | fukue
# Processing Record 8 of Set 6 | xingyi
# Processing Record 9 of Set 6 | pingchen
# City not found. Skipping...
# Processing Record 10 of Set 6 | constitucion
# Processing Record 11 of Set 6 | naze
# Processing Record 12 of Set 6 | flinders
# Processing Record 13 of Set 6 | dolbeau
# City not found. Skipping...
# Processing Record 14 of Set 6 | yerbogachen
# Processing Record 15 of Set 6 | hervey bay
# Processing Record 16 of Set 6 | wagar
# Processing Record 17 of Set 6 | victoria
# Processing Record 18 of Set 6 | kokomo
# Processing Record 19 of Set 6 | fortuna
# Processing Record 20 of Set 6 | asyut
# Processing Record 21 of Set 6 | najran
# Processing Record 22 of Set 6 | tevaitoa
# Processing Record 23 of Set 6 | vila
# Processing Record 24 of Set 6 | baillif
# Processing Record 25 of Set 6 | nortelandia
# Processing Record 26 of Set 6 | westpunt
# City not found. Skipping...
# Processing Record 27 of Set 6 | karabulak
# Processing Record 28 of Set 6 | sol-iletsk
# Processing Record 29 of Set 6 | tubruq
# City not found. Skipping...
# Processing Record 30 of Set 6 | barbar
# City not found. Skipping...
# Processing Record 31 of Set 6 | goderich
# Processing Record 32 of Set 6 | bowen
# Processing Record 33 of Set 6 | viedma
# Processing Record 34 of Set 6 | mayo
# Processing Record 35 of Set 6 | saint-pierre
# Processing Record 36 of Set 6 | zhicheng
# Processing Record 37 of Set 6 | qaqortoq
# Processing Record 38 of Set 6 | voskresenskoye
# Processing Record 39 of Set 6 | airai
# Processing Record 40 of Set 6 | san francisco del mar
# Processing Record 41 of Set 6 | santa maria
# Processing Record 42 of Set 6 | chiredzi
# Processing Record 43 of Set 6 | waingapu
# Processing Record 44 of Set 6 | mount gambier
# Processing Record 45 of Set 6 | mizdah
# Processing Record 46 of Set 6 | alegrete
# Processing Record 47 of Set 6 | safford
# Processing Record 48 of Set 6 | inderborskiy
# City not found. Skipping...
# Processing Record 49 of Set 6 | sigulda
# Processing Record 50 of Set 6 | dharmavaram
# Processing Record 1 of Set 7 | sioux city
# Processing Record 2 of Set 7 | baykit
# Processing Record 3 of Set 7 | hambantota
# Processing Record 4 of Set 7 | basco
# Processing Record 5 of Set 7 | egvekinot
# Processing Record 6 of Set 7 | chicama
# Processing Record 7 of Set 7 | severo-kurilsk
# Processing Record 8 of Set 7 | vao
# Processing Record 9 of Set 7 | karpathos
# Processing Record 10 of Set 7 | tefe
# Processing Record 11 of Set 7 | kabo
# Processing Record 12 of Set 7 | iranshahr
# Processing Record 13 of Set 7 | bargal
# City not found. Skipping...
# Processing Record 14 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 15 of Set 7 | tutoia
# Processing Record 16 of Set 7 | lodwar
# Processing Record 17 of Set 7 | mercedes
# Processing Record 18 of Set 7 | zhezkazgan
# Processing Record 19 of Set 7 | te anau
# Processing Record 20 of Set 7 | talnakh
# Processing Record 21 of Set 7 | chateaubelair
# Processing Record 22 of Set 7 | ambagarh chauki
# Processing Record 23 of Set 7 | tasbuget
# City not found. Skipping...
# Processing Record 24 of Set 7 | tiksi
# Processing Record 25 of Set 7 | buala
# Processing Record 26 of Set 7 | port blair
# Processing Record 27 of Set 7 | farmington
# Processing Record 28 of Set 7 | half moon bay
# Processing Record 29 of Set 7 | erenhot
# Processing Record 30 of Set 7 | umm durman
# City not found. Skipping...
# Processing Record 31 of Set 7 | louisbourg
# City not found. Skipping...
# Processing Record 32 of Set 7 | zharkent
# Processing Record 33 of Set 7 | labuhan
# Processing Record 34 of Set 7 | shimoda
# Processing Record 35 of Set 7 | bandarbeyla
# Processing Record 36 of Set 7 | rocha
# Processing Record 37 of Set 7 | paris
# Processing Record 38 of Set 7 | cherskiy
# Processing Record 39 of Set 7 | morondava
# Processing Record 40 of Set 7 | kuah
# Processing Record 41 of Set 7 | huarmey
# Processing Record 42 of Set 7 | marrakesh
# Processing Record 43 of Set 7 | mapimi
# Processing Record 44 of Set 7 | guhagar
# Processing Record 45 of Set 7 | ucluelet
# Processing Record 46 of Set 7 | necochea
# Processing Record 47 of Set 7 | malinovskiy
# Processing Record 48 of Set 7 | bambanglipuro
# Processing Record 49 of Set 7 | chokurdakh
# Processing Record 50 of Set 7 | veraval
# Processing Record 1 of Set 8 | namikupa
# Processing Record 2 of Set 8 | cabedelo
# Processing Record 3 of Set 8 | port-gentil
# Processing Record 4 of Set 8 | hithadhoo
# Processing Record 5 of Set 8 | iquique
# Processing Record 6 of Set 8 | axim
# Processing Record 7 of Set 8 | ahipara
# Processing Record 8 of Set 8 | port hardy
# Processing Record 9 of Set 8 | svetlyy
# Processing Record 10 of Set 8 | bathsheba
# Processing Record 11 of Set 8 | svetlaya
# Processing Record 12 of Set 8 | saurimo
# Processing Record 13 of Set 8 | mys shmidta
# City not found. Skipping...
# Processing Record 14 of Set 8 | belushya guba
# City not found. Skipping...
# Processing Record 15 of Set 8 | broome
# Processing Record 16 of Set 8 | seymchan
# Processing Record 17 of Set 8 | mantua
# Processing Record 18 of Set 8 | borovoy
# Processing Record 19 of Set 8 | nouakchott
# Processing Record 20 of Set 8 | bor
# Processing Record 21 of Set 8 | qui nhon
# Processing Record 22 of Set 8 | katherine
# Processing Record 23 of Set 8 | pisco
# Processing Record 24 of Set 8 | ceyhan
# Processing Record 25 of Set 8 | scarborough
# Processing Record 26 of Set 8 | hirara
# Processing Record 27 of Set 8 | newport
# Processing Record 28 of Set 8 | jalu
# Processing Record 29 of Set 8 | san policarpo
# Processing Record 30 of Set 8 | aksu
# Processing Record 31 of Set 8 | corrales
# Processing Record 32 of Set 8 | leningradskiy
# Processing Record 33 of Set 8 | conceicao da barra
# Processing Record 34 of Set 8 | ambatondrazaka
# Processing Record 35 of Set 8 | inirida
# Processing Record 36 of Set 8 | tura
# Processing Record 37 of Set 8 | bousso
# Processing Record 38 of Set 8 | majene
# Processing Record 39 of Set 8 | luganville
# Processing Record 40 of Set 8 | kazalinsk
# City not found. Skipping...
# Processing Record 41 of Set 8 | hillsborough
# Processing Record 42 of Set 8 | ngaoundere
# Processing Record 43 of Set 8 | sitka
# Processing Record 44 of Set 8 | wawa
# Processing Record 45 of Set 8 | muros
# Processing Record 46 of Set 8 | iqaluit
# Processing Record 47 of Set 8 | hamilton
# Processing Record 48 of Set 8 | port lavaca
# Processing Record 49 of Set 8 | bonavista
# Processing Record 50 of Set 8 | antagan
# City not found. Skipping...
# Processing Record 1 of Set 9 | verkhnyaya balkariya
# Processing Record 2 of Set 9 | severo-yeniseyskiy
# Processing Record 3 of Set 9 | zabol
# Processing Record 4 of Set 9 | payo
# Processing Record 5 of Set 9 | wulanhaote
# City not found. Skipping...
# Processing Record 6 of Set 9 | guilin
# Processing Record 7 of Set 9 | santa cruz cabralia
# Processing Record 8 of Set 9 | impfondo
# Processing Record 9 of Set 9 | yanam
# Processing Record 10 of Set 9 | brownwood
# Processing Record 11 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 12 of Set 9 | caconda
# Processing Record 13 of Set 9 | lima
# Processing Record 14 of Set 9 | aykhal
# Processing Record 15 of Set 9 | thinadhoo
# Processing Record 16 of Set 9 | onguday
# Processing Record 17 of Set 9 | guerrero negro
# Processing Record 18 of Set 9 | kupang
# Processing Record 19 of Set 9 | ballstad
# City not found. Skipping...
# Processing Record 20 of Set 9 | nampula
# Processing Record 21 of Set 9 | oeiras do para
# Processing Record 22 of Set 9 | karak
# Processing Record 23 of Set 9 | dinghai
# Processing Record 24 of Set 9 | mana
# Processing Record 25 of Set 9 | grajau
# Processing Record 26 of Set 9 | sidhauli
# Processing Record 27 of Set 9 | kavarskas
# Processing Record 28 of Set 9 | ewa beach
# Processing Record 29 of Set 9 | xochistlahuaca
# Processing Record 30 of Set 9 | yabrud
# Processing Record 31 of Set 9 | sinop
# Processing Record 32 of Set 9 | tir pol
# City not found. Skipping...
# Processing Record 33 of Set 9 | halifax
# Processing Record 34 of Set 9 | danilovka
# Processing Record 35 of Set 9 | kang
# Processing Record 36 of Set 9 | cabo san lucas
# Processing Record 37 of Set 9 | tukrah
# Processing Record 38 of Set 9 | seydi
# Processing Record 39 of Set 9 | yulara
# Processing Record 40 of Set 9 | papasquiaro
# City not found. Skipping...
# Processing Record 41 of Set 9 | manaquiri
# Processing Record 42 of Set 9 | manzanillo
# Processing Record 43 of Set 9 | dzhusaly
# City not found. Skipping...
# Processing Record 44 of Set 9 | longlac
# City not found. Skipping...
# Processing Record 45 of Set 9 | paita
# Processing Record 46 of Set 9 | cuamba
# Processing Record 47 of Set 9 | upington
# Processing Record 48 of Set 9 | esmeraldas
# Processing Record 49 of Set 9 | uaua
# Processing Record 50 of Set 9 | danielskuil
# Processing Record 1 of Set 10 | salalah
# Processing Record 2 of Set 10 | eyl
# Processing Record 3 of Set 10 | palana
# Processing Record 4 of Set 10 | ryotsu
# Processing Record 5 of Set 10 | saint-louis
# Processing Record 6 of Set 10 | mugla
# Processing Record 7 of Set 10 | atascocita
# Processing Record 8 of Set 10 | am timan
# Processing Record 9 of Set 10 | vicuna
# Processing Record 10 of Set 10 | orlik
# Processing Record 11 of Set 10 | tessalit
# Processing Record 12 of Set 10 | marystown
# Processing Record 13 of Set 10 | yuxia
# Processing Record 14 of Set 10 | west bay
# Processing Record 15 of Set 10 | quimper
# Processing Record 16 of Set 10 | pimentel
# Processing Record 17 of Set 10 | yar-sale
# Processing Record 18 of Set 10 | naziya
# Processing Record 19 of Set 10 | doha
# Processing Record 20 of Set 10 | kandrian
# Processing Record 21 of Set 10 | laurel
# Processing Record 22 of Set 10 | ust-ilimsk
# Processing Record 23 of Set 10 | maldonado
# Processing Record 24 of Set 10 | gazojak
# Processing Record 25 of Set 10 | alofi
# Processing Record 26 of Set 10 | nouadhibou
# Processing Record 27 of Set 10 | adrar
# Processing Record 28 of Set 10 | grand-santi
# Processing Record 29 of Set 10 | jabiru
# City not found. Skipping...
# Processing Record 30 of Set 10 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 31 of Set 10 | celestun
# Processing Record 32 of Set 10 | touros
# Processing Record 33 of Set 10 | san anselmo
# Processing Record 34 of Set 10 | morant bay
# Processing Record 35 of Set 10 | muisne
# Processing Record 36 of Set 10 | attawapiskat
# City not found. Skipping...
# Processing Record 37 of Set 10 | camargo
# Processing Record 38 of Set 10 | georgiyevskoye
# Processing Record 39 of Set 10 | pind dadan khan
# Processing Record 40 of Set 10 | lishan
# Processing Record 41 of Set 10 | chipinge
# Processing Record 42 of Set 10 | los llanos de aridane
# Processing Record 43 of Set 10 | bimbo
# Processing Record 44 of Set 10 | burgeo
# Processing Record 45 of Set 10 | lompoc
# Processing Record 46 of Set 10 | along
# Processing Record 47 of Set 10 | havre-saint-pierre
# Processing Record 48 of Set 10 | port macquarie
# Processing Record 49 of Set 10 | lolua
# City not found. Skipping...
# Processing Record 50 of Set 10 | rio rancho
# Processing Record 1 of Set 11 | key west
# Processing Record 2 of Set 11 | feijo
# Processing Record 3 of Set 11 | anage
# Processing Record 4 of Set 11 | vestmannaeyjar
# Processing Record 5 of Set 11 | thabazimbi
# Processing Record 6 of Set 11 | hay river
# Processing Record 7 of Set 11 | goya
# Processing Record 8 of Set 11 | oyem
# Processing Record 9 of Set 11 | tabou
# Processing Record 10 of Set 11 | loveland
# Processing Record 11 of Set 11 | xucheng
# Processing Record 12 of Set 11 | pasni
# Processing Record 13 of Set 11 | evensk
# Processing Record 14 of Set 11 | pitea
# Processing Record 15 of Set 11 | autun
# Processing Record 16 of Set 11 | mglin
# Processing Record 17 of Set 11 | beldanga
# Processing Record 18 of Set 11 | carutapera
# Processing Record 19 of Set 11 | tingi
# Processing Record 20 of Set 11 | la sarre
# Processing Record 21 of Set 11 | makurdi
# Processing Record 22 of Set 11 | presidencia roque saenz pena
# Processing Record 23 of Set 11 | oistins
# Processing Record 24 of Set 11 | lethem
# Processing Record 25 of Set 11 | nha trang
# Processing Record 26 of Set 11 | soria
# Processing Record 27 of Set 11 | yenagoa
# Processing Record 28 of Set 11 | anadyr
# Processing Record 29 of Set 11 | emerald
# Processing Record 30 of Set 11 | glyadyanskoye
# Processing Record 31 of Set 11 | knysna
# Processing Record 32 of Set 11 | bykovo
# Processing Record 33 of Set 11 | inta
# Processing Record 34 of Set 11 | waipawa
# Processing Record 35 of Set 11 | kankon
# Processing Record 36 of Set 11 | avenal
# Processing Record 37 of Set 11 | mendahara
# City not found. Skipping...
# Processing Record 38 of Set 11 | bonthe
# Processing Record 39 of Set 11 | rio pomba
# Processing Record 40 of Set 11 | aranos
# Processing Record 41 of Set 11 | whyalla
# Processing Record 42 of Set 11 | dongying
# Processing Record 43 of Set 11 | xapuri
# Processing Record 44 of Set 11 | brive-la-gaillarde
# Processing Record 45 of Set 11 | cheuskiny
# City not found. Skipping...
# Processing Record 46 of Set 11 | dunedin
# Processing Record 47 of Set 11 | saint-augustin
# Processing Record 48 of Set 11 | cortez
# Processing Record 49 of Set 11 | ust-kut
# Processing Record 50 of Set 11 | skibbereen
# Processing Record 1 of Set 12 | sao filipe
# Processing Record 2 of Set 12 | ulladulla
# Processing Record 3 of Set 12 | aswan
# Processing Record 4 of Set 12 | nueve de julio
# Processing Record 5 of Set 12 | huacho
# Processing Record 6 of Set 12 | ambilobe
# Processing Record 7 of Set 12 | menongue
# Processing Record 8 of Set 12 | zyryanka
# Processing Record 9 of Set 12 | sao felix do xingu
# Processing Record 10 of Set 12 | saldanha
# Processing Record 11 of Set 12 | valparaiso
# Processing Record 12 of Set 12 | kununurra
# Processing Record 13 of Set 12 | jiuquan
# Processing Record 14 of Set 12 | esil
# Processing Record 15 of Set 12 | hibbing
# Processing Record 16 of Set 12 | turayf
# Processing Record 17 of Set 12 | alice springs
# Processing Record 18 of Set 12 | tapaua
# City not found. Skipping...
# Processing Record 19 of Set 12 | waw
# Processing Record 20 of Set 12 | chaa-khol
# City not found. Skipping...
# Processing Record 21 of Set 12 | amlame
# Processing Record 22 of Set 12 | shenjiamen
# Processing Record 23 of Set 12 | wajima
# Processing Record 24 of Set 12 | puerto del rosario
# Processing Record 25 of Set 12 | vrangel
# Processing Record 26 of Set 12 | salo
# Processing Record 27 of Set 12 | pacific grove
# Processing Record 28 of Set 12 | vardo
# Processing Record 29 of Set 12 | road town
# Processing Record 30 of Set 12 | srednekolymsk
# Processing Record 31 of Set 12 | rosarito
# Processing Record 32 of Set 12 | henties bay
# Processing Record 33 of Set 12 | erzurum
# Processing Record 34 of Set 12 | barreirinha
# Processing Record 35 of Set 12 | juneau
# Processing Record 36 of Set 12 | hastings
# Processing Record 37 of Set 12 | san andres
# Processing Record 38 of Set 12 | tillabery
# City not found. Skipping...
# Processing Record 39 of Set 12 | imbituba
# Processing Record 40 of Set 12 | tolu
# Processing Record 41 of Set 12 | pulaski
# Processing Record 42 of Set 12 | marzuq
# Processing Record 43 of Set 12 | muli
# Processing Record 44 of Set 12 | nuqui
# Processing Record 45 of Set 12 | polyarnyy
# Processing Record 46 of Set 12 | salta
# Processing Record 47 of Set 12 | havoysund
# Processing Record 48 of Set 12 | khasan
# Processing Record 49 of Set 12 | piacabucu
# Processing Record 50 of Set 12 | hearst
# Processing Record 1 of Set 13 | ayna
# Processing Record 2 of Set 13 | breclav
# Processing Record 3 of Set 13 | takhtamygda
# Processing Record 4 of Set 13 | santa lucia
# Processing Record 5 of Set 13 | birjand
# Processing Record 6 of Set 13 | salyan
# Processing Record 7 of Set 13 | vila franca do campo
# Processing Record 8 of Set 13 | jawhar
# Processing Record 9 of Set 13 | pimenteiras
# Processing Record 10 of Set 13 | matara
# Processing Record 11 of Set 13 | gravdal
# Processing Record 12 of Set 13 | great yarmouth
# Processing Record 13 of Set 13 | nhulunbuy
# Processing Record 14 of Set 13 | biltine
# Processing Record 15 of Set 13 | korla
# Processing Record 16 of Set 13 | pouebo
# Processing Record 17 of Set 13 | pagudpud
# Processing Record 18 of Set 13 | rio cuarto
# Processing Record 19 of Set 13 | petropavlovsk-kamchatskiy
# Processing Record 20 of Set 13 | kyzyl-suu
# Processing Record 21 of Set 13 | ngukurr
# City not found. Skipping...
# Processing Record 22 of Set 13 | broken hill
# Processing Record 23 of Set 13 | olafsvik
# Processing Record 24 of Set 13 | komsomolskiy
# Processing Record 25 of Set 13 | tahe
# Processing Record 26 of Set 13 | zsombo
# Processing Record 27 of Set 13 | siwani
# City not found. Skipping...
# Processing Record 28 of Set 13 | indianola
# Processing Record 29 of Set 13 | ekhabi
# Processing Record 30 of Set 13 | xilitla
# Processing Record 31 of Set 13 | jacareacanga
# Processing Record 32 of Set 13 | qazvin
# Processing Record 33 of Set 13 | prince george
# Processing Record 34 of Set 13 | coari
# Processing Record 35 of Set 13 | abu samrah
# Processing Record 36 of Set 13 | filadelfia
# Processing Record 37 of Set 13 | salinas
# Processing Record 38 of Set 13 | billings
# Processing Record 39 of Set 13 | margate
# Processing Record 40 of Set 13 | nemuro
# Processing Record 41 of Set 13 | karasjok
# Processing Record 42 of Set 13 | batagay-alyta
# Processing Record 43 of Set 13 | osterhofen
# Processing Record 44 of Set 13 | bubaque
# Processing Record 45 of Set 13 | oksfjord
# Processing Record 46 of Set 13 | kargat
# Processing Record 47 of Set 13 | yanan
# City not found. Skipping...
# Processing Record 48 of Set 13 | yavaros
# Processing Record 49 of Set 13 | praia da vitoria
# Processing Record 50 of Set 13 | ayagoz
# Processing Record 1 of Set 14 | benguela
# Processing Record 2 of Set 14 | kalmunai
# Processing Record 3 of Set 14 | romanovo
# Processing Record 4 of Set 14 | gazanjyk
# Processing Record 5 of Set 14 | labuan
# Processing Record 6 of Set 14 | trairi
# Processing Record 7 of Set 14 | haines junction
# Processing Record 8 of Set 14 | bilibino
# Processing Record 9 of Set 14 | sur
# Processing Record 10 of Set 14 | miguel auza
# Processing Record 11 of Set 14 | dolores
# Processing Record 12 of Set 14 | ypsonas
# Processing Record 13 of Set 14 | toamasina
# Processing Record 14 of Set 14 | tanggu
# Processing Record 15 of Set 14 | katobu
# Processing Record 16 of Set 14 | qianan
# Processing Record 17 of Set 14 | sanghar
# Processing Record 18 of Set 14 | belaya gora
# Processing Record 19 of Set 14 | dawson creek
# Processing Record 20 of Set 14 | lake cowichan
# Processing Record 21 of Set 14 | pudozh
# Processing Record 22 of Set 14 | eureka
# Processing Record 23 of Set 14 | eyemouth
# Processing Record 24 of Set 14 | matagami
# Processing Record 25 of Set 14 | platanos
# Processing Record 26 of Set 14 | itapirapua
# Processing Record 27 of Set 14 | ternate
# Processing Record 28 of Set 14 | russell
# Processing Record 29 of Set 14 | dingle
# Processing Record 30 of Set 14 | colborne
# Processing Record 31 of Set 14 | juanjui
# Processing Record 32 of Set 14 | sangar
# Processing Record 33 of Set 14 | karpogory
# Processing Record 34 of Set 14 | campos do jordao
# Processing Record 35 of Set 14 | kangavar
# Processing Record 36 of Set 14 | andenes
# Processing Record 37 of Set 14 | oume
# Processing Record 38 of Set 14 | entre rios
# Processing Record 39 of Set 14 | camabatela
# Processing Record 40 of Set 14 | cape coast
# Processing Record 41 of Set 14 | belmonte
# Processing Record 42 of Set 14 | safaqis
# City not found. Skipping...
# Processing Record 43 of Set 14 | tobermory
# Processing Record 44 of Set 14 | shache
# Processing Record 45 of Set 14 | douentza
# Processing Record 46 of Set 14 | qasigiannguit
# Processing Record 47 of Set 14 | lincoln
# Processing Record 48 of Set 14 | mattru
# Processing Record 49 of Set 14 | malanje
# Processing Record 50 of Set 14 | roald
# Processing Record 1 of Set 15 | balikpapan
# Processing Record 2 of Set 15 | miri
# Processing Record 3 of Set 15 | timizart
# Processing Record 4 of Set 15 | burgersdorp
# Processing Record 5 of Set 15 | nguiu
# City not found. Skipping...
# Processing Record 6 of Set 15 | noyabrsk
# Processing Record 7 of Set 15 | mahaicony
# City not found. Skipping...
# Processing Record 8 of Set 15 | salinopolis
# Processing Record 9 of Set 15 | paamiut
# Processing Record 10 of Set 15 | kolindros
# Processing Record 11 of Set 15 | yingcheng
# Processing Record 12 of Set 15 | alihe
# Processing Record 13 of Set 15 | ingham
# Processing Record 14 of Set 15 | yuzhou
# Processing Record 15 of Set 15 | kultuk
# Processing Record 16 of Set 15 | micheweni
# Processing Record 17 of Set 15 | cururupu
# Processing Record 18 of Set 15 | duminichi
# Processing Record 19 of Set 15 | santa ana
# Processing Record 20 of Set 15 | mocambique
# City not found. Skipping...
# Processing Record 21 of Set 15 | rawson
# Processing Record 22 of Set 15 | daru
# Processing Record 23 of Set 15 | sao jose da coroa grande
# Processing Record 24 of Set 15 | whitehorse
# Processing Record 25 of Set 15 | arrifes
# Processing Record 26 of Set 15 | ramshir
# Processing Record 27 of Set 15 | puquio
# Processing Record 28 of Set 15 | kamenka
# Processing Record 29 of Set 15 | tyler
# Processing Record 30 of Set 15 | fairbanks
# Processing Record 31 of Set 15 | guanica
# Processing Record 32 of Set 15 | banaue
# Processing Record 33 of Set 15 | meyungs
# City not found. Skipping...
# Processing Record 34 of Set 15 | zhanaozen
# Processing Record 35 of Set 15 | bereda
# Processing Record 36 of Set 15 | steinbach
# Processing Record 37 of Set 15 | sovetskaya gavan
# Processing Record 38 of Set 15 | kismayo
# Processing Record 39 of Set 15 | lasa
# Processing Record 40 of Set 15 | haibowan
# City not found. Skipping...
# Processing Record 41 of Set 15 | itoman
# Processing Record 42 of Set 15 | rio grande
# Processing Record 43 of Set 15 | maimon
# City not found. Skipping...
# Processing Record 44 of Set 15 | opuwo
# Processing Record 45 of Set 15 | sidi ali
# Processing Record 46 of Set 15 | ribeira brava
# Processing Record 47 of Set 15 | valdivia
# Processing Record 48 of Set 15 | gao
# Processing Record 49 of Set 15 | atambua
# Processing Record 50 of Set 15 | sal rei
# Processing Record 1 of Set 16 | gazni
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
new_column_order = ['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'Current Description']
city_data_df = city_data_df[new_column_order]
city_data_df.tail()
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 686  Ribeira Brava      PT  32.6500  -17.0667     72.23        77          99
# 687       Valdivia      CL -39.8142  -73.2459     48.29        98           0
# 688            Gao      ML  16.6362    1.6370     82.85        10          10
# 689        Atambua      ID  -9.1061  124.8925     86.34        41          24
# 690        Sal Rei      CV  16.1833  -22.9167     77.56        82          52
#
#      Wind Speed Current Description
# 686        3.36     overcast clouds
# 687        1.45           clear sky
# 688       10.78           clear sky
# 689        1.57          few clouds
# 690       11.21       broken clouds

# %%
# Create the output file (CSV).
Output_Data_File = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(Output_Data_File, index_label="City_ID")
